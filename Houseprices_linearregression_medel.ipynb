# %% [markdown]
# <a href="https://colab.research.google.com/github/MSSAMAJA/houseprice_MLlinearregressionmodel/blob/main/Houseprices_linearregression_medel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linearregressionmodel

# %%
#Given a dataset of house prices and features like size, number of rooms, etc

# %%
#random data

# %%
import pandas as pd
import numpy as np

# Generate a larger dataset
np.random.seed(42)

size = np.random.randint(1000, 5000, 100)   # House sizes between 1000 and 5000 sq ft
rooms = np.random.randint(1, 8, 100)        # Number of rooms between 1 and 7
price = size * 150 + rooms * 25000 + np.random.randint(-50000, 50000, 100)  # Price based on size and rooms

data = {
    'Size': size,
    'Rooms': rooms,
    'Price': price
}

# %%
#create a dataframe

# %%
import pandas as pd
df=pd.DataFrame(data)
print(df)
# Out:
#     Size  Rooms   Price
# 0   4174      2  659927
# 1   4507      2  731870
# 2   1860      4  391623
# 3   2294      2  425834
# 4   2130      2  394950
# ..   ...    ...     ...
# 95  2129      7  447161
# 96  4843      5  857700
# 97  4893      7  931032
# 98  2500      3  434754
# 99  1702      5  426042
#
# [100 rows x 3 columns]

# %%
#define target

# %%
#continues variable, target variable= Price(y)
#price can be dependent on both size and the room number
#analysing the data set, size is a better option
#defining the varibles

# %%
y=df['Price']
X=df[['Size','Rooms']]

# %%
y.shape
# Out:
# (100,)

# %%
X.shape
# Out:
# (100, 2)

# %%
#import train_test_split

from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=2529)

# %%
X_train
# Out:
#     Size  Rooms
# 46  1975      7
# 53  2899      2
# 3   2294      2
# 66  3435      5
# 26  3853      1
# ..   ...    ...
# 47  2806      2
# 15  4444      5
# 60  4890      4
# 50  3734      7
# 96  4843      5
#
# [80 rows x 2 columns]

# %%
X_test
# Out:
#     Size  Rooms
# 93  4461      5
# 9   3169      7
# 82  3556      2
# 81  4499      2
# 27  3433      5
# 45  3747      2
# 44  4547      5
# 63  3888      3
# 69  3061      3
# 76  2363      7
# 6   4772      4
# 21  4380      1
# 38  4632      3
# 39  1474      1
# 98  2500      3
# 79  4003      7
# 70  1241      1
# 89  4943      4
# 4   2130      2
# 12  1330      4

# %%
#importing the model selected

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
#fitting the model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([  151.95439512, 23600.12271078])

# %%
model.intercept_
# Out:
# 1123.4350237282924

# %%
#linear equation would be y=1123.435+151.954⋅x1+23600.123⋅x2

# %%
#predicting
y_pred=model.predict(X_test)
y_pred
# Out:
# array([796992.60522991, 647867.77215007, 588673.50950952, 731966.50411232,
#        640783.48704149, 617696.79897838, 810060.68321066, 662722.49140177,
#        537056.20663346, 525392.52967938, 820650.29940299, 690283.80838168,
#        775776.56137472, 248704.33614865, 451809.79096838, 774597.73768426,
#        213298.96208454, 846634.50096935, 371986.54206138, 297623.271383  ])

# %%
#testing the accuracy
from sklearn.metrics import mean_absolute_percentage_error

# %%
error=mean_absolute_percentage_error(y_test,y_pred)
error
# Out:
# 0.04704514865235371

# %%
accuracy = 100 - error
accuracy
# Out:
# 99.95295485134764

# %%
#this model is 99% accurate
